# %%
# %cd git-activity-GabyGaby412
# Out:
# /Users/gabrielavelazquez/Downloads/git-activity-GabyGaby412

# %%
# !git add Markdown-for-Git.ipynb
# Out:
# fatal: pathspec 'Markdown-for-Git.ipynb' did not match any files
